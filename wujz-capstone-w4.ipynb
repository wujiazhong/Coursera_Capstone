# %% [markdown]
# # Introduction

# %% [markdown]
# In this project, the similarity between Manhattan (New York) and Downtown Toronto (Toronto) will be compared. Say that there will be a upcoming holiday and you have two options for visit:  New York and Toronto. Which one would you like to go? Let's compare them from the counts of Coffee Shop, Hotel, Café, Restaurant, Gastropub.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# First of all, we need get geo data of two cities from website.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Preapre geo data for New York

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_ny_data = newyork_data['features']

# %%
neighborhoods_ny_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods_ny = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_ny_data:
    borough = data['properties']['borough'] 
    neighborhood_ny_name = data['properties']['name']
        
    neighborhood_ny_latlon = data['geometry']['coordinates']
    neighborhood_ny_lat = neighborhood_ny_latlon[1]
    neighborhood_ny_lon = neighborhood_ny_latlon[0]
    
    neighborhoods_ny = neighborhoods_ny.append({'Borough': borough,
                                          'Neighborhood': neighborhood_ny_name,
                                          'Latitude': neighborhood_ny_lat,
                                          'Longitude': neighborhood_ny_lon}, ignore_index=True)

# %%
neighborhoods_ny.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
manhattan_data = neighborhoods_ny[neighborhoods_ny['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# ### Prepare geo data for Toronto

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(response.text, features="html.parser")

table_data = soup.select('table.wikitable.sortable > tbody > tr')
theads = table_data[0].select('th')
trows = table_data[1:]

columns = []
for thead in theads:
    columns.append(thead.get_text().strip())

data_rows = [[] for col in columns]
for row in trows:
    tds = row.select('td')
    for idx, td in enumerate(tds):
        data_rows[idx].append(td.get_text().strip())

trt = pd.DataFrame()
for idx, col in enumerate(columns):
    trt[col] = data_rows[idx]

trt.to_csv(r'toronto_neighbor.csv', index=False)

# %%
trt.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
def get_pos(address):
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    if location is None:
        return [0,0]
    latitude = location.latitude
    longitude = location.longitude
    print(address, latitude, longitude)
    return [latitude, longitude]

# %%
trt['Neighbourhood_Toronto'] = trt['Neighbourhood'] + ', Toronto'
new_cols = trt['Neighbourhood_Toronto'].apply(lambda nbh: get_pos(nbh))

trt['Latitude'] = new_cols.apply(lambda x: x[0])
trt['Longitude'] = new_cols.apply(lambda x: x[1])
trt = trt[trt['Latitude'] != 0.0]
trt = trt[trt['Longitude'] != 0.0]
trt.reset_index(drop=True, inplace=True)
trt.head()
# Out:
# Parkwoods, Toronto 43.7611243 -79.3240594
# Victoria Village, Toronto 43.732658 -79.3111892
# Harbourfront, Toronto 43.6400801 -79.3801495
# Regent Park, Toronto 43.6607056 -79.3604569
# Lawrence Heights, Toronto 43.7227784 -79.4509332
# Lawrence Manor, Toronto 43.7220788 -79.4375067
# Islington Avenue, Toronto 43.7192407 -79.5570574
# Rouge, Toronto 43.8049304 -79.1658374
# Malvern, Toronto 43.8091955 -79.2217008
# Don Mills North, Toronto 43.737178 -79.3434514
# Woodbine Gardens, Toronto 43.7120785 -79.3025673
# Parkview Hill, Toronto 43.7062977 -79.3219073
# Ryerson, Toronto 43.65815275 -79.37908010263
# Garden District, Toronto 43.6565019 -79.3771275
# Glencairn, Toronto 43.7087117 -79.4406853
# Cloverdale, Toronto 43.633637 -79.5497447
# Islington, Toronto 43.6453376 -79.52487
# Martin Grove, Toronto 43.653963 -79.387207
# Princess Gardens, Toronto 43.6404664 -79.3912237
# West Deane Park, Toronto 43.6631995 -79.5685684
# Highland Creek, Toronto 43.7901172 -79.1733344
# Rouge Hill, Toronto 43.7802711 -79.1304992
# Port Union, Toronto 43.7755039 -79.1349765
# Flemingdon Park, Toronto 43.7184315 -79.333204
# Don Mills South, Toronto 43.737178 -79.3434514
# Woodbine Heights, Toronto 43.6999302 -79.3191316
# St. James Town, Toronto 43.6694032 -79.3727041
# Bloordale Gardens, Toronto 43.6353169 -79.5636744
# Eringate, Toronto 43.6622732 -79.5765162
# Markland Wood, Toronto 43.63123795 -79.5854368166265
# Old Burnhamthorpe, Toronto 43.6393732 -79.5843869
# Guildwood, Toronto 43.7548985 -79.1977755
# Morningside, Toronto 43.7826012 -79.2049579
# West Hill, Toronto 43.7689144 -79.1872905
# The Beaches, Toronto 43.6710244 -79.296712
# Berczy Park, Toronto 43.6479887 -79.3753927260178
# Woburn, Toronto 43.7598243 -79.2252908
# Leaside, Toronto 43.7047983 -79.3680904
# Central Bay Street, Toronto 49.8653059 14.4725114
# Christie, Toronto 43.6641106 -79.4184051
# Cedarbrae, Toronto 43.75646655 -79.226692442588
# Hillcrest Village, Toronto 43.7996637 -79.3650189
# Bathurst Manor, Toronto 43.76389295 -79.4563669371095
# Downsview North, Toronto 43.7492988 -79.462248
# Wilson Heights, Toronto 43.7405195 -79.4400172
# Thorncliffe Park, Toronto 43.704553 -79.3454074
# Adelaide, Toronto 43.6505275 -79.3795145502646
# King, Toronto 43.6489494 -79.3777538
# Richmond, Toronto 43.6500202 -79.3865866
# Dovercourt Village, Toronto 43.6653069 -79.4326362
# Dufferin, Toronto 43.6602019 -79.4357191
# Scarborough Village, Toronto 43.7437422 -79.2116324
# Fairview, Toronto 43.653963 -79.387207
# Henry Farm, Toronto 43.7695089 -79.354296
# Oriole, Toronto 43.7649819 -79.3642488
# Northwood Park, Toronto 43.7541351 -79.50448
# York University, Toronto 43.7740965 -79.4995213
# East Toronto, Toronto 43.653963 -79.387207
# Harbourfront East, Toronto 43.6400801 -79.3801495
# Toronto Islands, Toronto 43.6161962 -79.3693582
# Union Station, Toronto 43.64469 -79.3799656881095
# Little Portugal, Toronto 43.64741325 -79.4311163254605
# Trinity, Toronto 43.65467605 -79.3817313765644
# East Birchmount Park, Toronto 43.7141672 -79.271109
# Ionview, Toronto 43.7359904 -79.2765146
# Kennedy Park, Toronto 43.724878 -79.2539688
# Bayview Village, Toronto 43.7691966 -79.3766617
# Downsview East, Toronto 43.7492988 -79.462248
# The Danforth West, Toronto 43.6863598 -79.3003158
# Riverdale, Toronto 43.6654704 -79.3525936
# Design Exchange, Toronto 43.6477412 -79.3801145
# Toronto Dominion Centre, Toronto 43.64736955 -79.3813733580709
# Brockton, Toronto 43.6509173 -79.4400216
# Exhibition Place, Toronto 43.63381345 -79.417140724094
# Parkdale Village, Toronto 43.6404954 -79.4368965
# Clairlea, Toronto 43.7088231 -79.2959856
# Golden Mile, Toronto 43.7278414 -79.2876217
# Oakridge, Toronto 43.6971738 -79.2748232
# Silver Hills, Toronto 43.7612224 -79.3683818
# York Mills, Toronto 43.7461836 -79.4204541
# Downsview West, Toronto 43.7492988 -79.462248
# The Beaches West, Toronto 43.6710244 -79.296712
# India Bazaar, Toronto 43.6722231 -79.3235032
# Commerce Court, Toronto 43.64809515 -79.3790207204735
# Victoria Hotel, Toronto 43.66946915 -79.37326825
# Downsview, Toronto 43.7492988 -79.462248
# North Park, Toronto 43.7186899 -79.4775337
# Upwood Park, Toronto 43.7089606 -79.5008945986058
# Humber Summit, Toronto 43.7600778 -79.5717598
# Cliffcrest, Toronto 43.7219387 -79.2362324
# Cliffside, Toronto 43.7111699 -79.2481769
# Scarborough Village West, Toronto 43.7437422 -79.2116324
# Newtonbrook, Toronto 43.7938863 -79.4256790230105
# Willowdale, Toronto 43.7753558 -79.4166859823926
# Downsview Central, Toronto 43.7492988 -79.462248
# Studio District, Toronto 43.6444029 -79.3878907
# Bedford Park, Toronto 43.7373876 -79.4109253
# Lawrence Manor East, Toronto 43.7220788 -79.4375067
# Keelesdale, Toronto 43.690157 -79.4750564
# Mount Dennis, Toronto 43.6869597 -79.4895513
# Silverthorn, Toronto 43.682123 -79.4715724
# Emery, Toronto 43.7520744 -79.5423657
# Humberlea, Toronto 43.7213166 -79.5331605
# Birch Cliff, Toronto 43.70211215 -79.2600905301568
# Cliffside West, Toronto 43.7111699 -79.2481769
# Willowdale South, Toronto 43.7753558 -79.4166859823926
# Downsview Northwest, Toronto 43.7492988 -79.462248
# Lawrence Park, Toronto 43.729199 -79.4032525
# Roselawn, Toronto 43.7069805 -79.4179415
# The Junction North, Toronto 43.6654775 -79.470352
# Runnymede, Toronto 43.6655802 -79.4821078
# Weston, Toronto 43.7001608 -79.5162474
# Dorset Park, Toronto 43.7528467 -79.282067
# Scarborough Town Centre, Toronto 43.7761255 -79.2584355948573
# Wexford Heights, Toronto 43.7432421 -79.304641
# York Mills West, Toronto 43.7440391 -79.406657
# Davisville North, Toronto 43.7043123 -79.3885169
# Forest Hill North, Toronto 43.6935586 -79.4139023
# Forest Hill West, Toronto 43.6935586 -79.4139023
# High Park, Toronto 43.64628135 -79.4638213811953
# The Junction South, Toronto 43.6654775 -79.470352
# Westmount, Toronto 43.6936399 -79.5210426
# Maryvale, Toronto 43.7590508 -79.3102297
# Wexford, Toronto 43.7453767 -79.2947155
# Willowdale West, Toronto 43.7753558 -79.4166859823926
# North Toronto West, Toronto 43.653963 -79.387207
# The Annex, Toronto 43.6703377 -79.407117
# North Midtown, Toronto 43.1621276 -77.6196036
# Yorkville, Toronto 43.6713861 -79.3901677
# Parkdale, Toronto 43.6404954 -79.4368965
# Roncesvalles, Toronto 43.6514426 -79.4510381
# Kingsview Village, Toronto 43.6995391 -79.5563459
# Martin Grove Gardens, Toronto 43.6873105 -79.561967
# Richview Gardens, Toronto 43.6848335 -79.5482883
# St. Phillips, Toronto 43.7000483 -79.5437651
# Agincourt, Toronto 43.7853531 -79.2785494
# Davisville, Toronto 43.7043123 -79.3885169
# Harbord, Toronto 43.6615225 -79.4097446
# University of Toronto, Toronto 43.6635094 -79.3977783616393
# Runnymede, Toronto 43.6655802 -79.4821078
# Swansea, Toronto 43.64494 -79.478313
# Clarks Corners, Toronto 43.7964095 -79.2977951
# Sullivan, Toronto 43.7726802 -79.3159449
# Tam O'Shanter, Toronto 43.7810454 -79.2980941
# Moore Park, Toronto 43.6903876 -79.3832965
# Summerhill East, Toronto 43.6816776 -79.3905037
# Chinatown, Toronto 43.6529237 -79.3980316
# Grange Park, Toronto 43.6521919 -79.3921942591534
# Kensington Market, Toronto 43.6552136 -79.4022604
# Agincourt North, Toronto 43.8080383 -79.2664391
# L'Amoreaux East, Toronto 43.799003 -79.3059669
# Milliken, Toronto 43.8232173 -79.3015232
# Steeles East, Toronto 43.8161778 -79.3145378
# Deer Park, Toronto 43.68809 -79.3940935
# Forest Hill SE, Toronto 43.6935586 -79.4139023
# Rathnelly, Toronto 43.6774724 -79.4004598
# South Hill, Toronto 43.6779261 -79.4057671
# Summerhill West, Toronto 43.6816776 -79.3905037
# CN Tower, Toronto 43.6425637 -79.3870871832047
# Bathurst Quay, Toronto 43.6357905 -79.398329
# Island airport, Toronto 43.65299685 -79.6006688518877
# Harbourfront West, Toronto 43.6400801 -79.3801495
# King and Spadina, Toronto 43.6454561 -79.3949942
# Railway Lands, Toronto 49.2662479 -123.2370252
# South Niagara, Toronto 43.64381725 -79.4081508139188
# Mimico South, Toronto 43.6036604 -79.4932037
# New Toronto, Toronto 43.6007625 -79.505264
# Albion Gardens, Toronto 43.7416654 -79.5845433686249
# Humbergate, Toronto 43.72852965 -79.6062403094193
# Jamestown, Toronto 43.653963 -79.387207
# Mount Olive, Toronto 43.653963 -79.387207
# Silverstone, Toronto 43.7497509 -79.5991159310942
# South Steeles, Toronto 43.8161778 -79.3145378
# Thistletown, Toronto 43.7372656 -79.5653169
# L'Amoreaux West, Toronto 43.799003 -79.3059669
# Rosedale, Toronto 43.6783556 -79.3807457
# Alderwood, Toronto 43.6017173 -79.5452325
# Long Branch, Toronto 43.5930751 -79.541212
# Northwest, Toronto 43.653963 -79.387207
# Upper Rouge, Toronto 43.8049304 -79.1658374
# Cabbagetown, Toronto 43.6644734 -79.3669861
# St. James Town, Toronto 43.6694032 -79.3727041
# First Canadian Place, Toronto 43.6487681 -79.3816917928303
# Underground city, Toronto 43.7701454 -79.3748625
# The Kingsway, Toronto 43.6473811 -79.5113328
# Montgomery Road, Toronto 43.6495494 -79.5199092
# Old Mill North, Toronto 43.6513012 -79.4954753
# Church and Wellesley, Toronto 43.6655242 -79.3838011
# Humber Bay, Toronto 43.6400463 -79.495028
# King's Mill Park, Toronto 43.6510895 -79.4920291
# Kingsway Park South East, Toronto 43.6473811 -79.5113328
# Mimico NE, Toronto 43.6036604 -79.4932037
# Old Mill South, Toronto 43.6513012 -79.4954753
# The Queensway East, Toronto 43.6093093 -79.5677317
# Royal York South East, Toronto 43.6481827 -79.5112961
# Sunnylea, Toronto 43.64159705 -79.5016649732138
# Kingsway Park South West, Toronto 43.6473811 -79.5113328
# Mimico NW, Toronto 43.6036604 -79.4932037
# The Queensway West, Toronto 43.6376722 -79.4674687
# Royal York South West, Toronto 43.6481827 -79.5112961
#   Postcode           Borough     Neighbourhood      Neighbourhood_Toronto  \
# 0      M3A        North York         Parkwoods         Parkwoods, Toronto
# 1      M4A        North York  Victoria Village  Victoria Village, Toronto
# 2      M5A  Downtown Toronto      Harbourfront      Harbourfront, Toronto
# 3      M5A  Downtown Toronto       Regent Park       Regent Park, Toronto
# 4      M6A        North York  Lawrence Heights  Lawrence Heights, Toronto
#
#     Latitude  Longitude
# 0  43.761124 -79.324059
# 1  43.732658 -79.311189
# 2  43.640080 -79.380150
# 3  43.660706 -79.360457
# 4  43.722778 -79.450933

# %%
trtdowntown_data = trt[trt['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
trtdowntown_data.head()
# Out:
#   Postcode           Borough    Neighbourhood     Neighbourhood_Toronto  \
# 0      M5A  Downtown Toronto     Harbourfront     Harbourfront, Toronto
# 1      M5A  Downtown Toronto      Regent Park      Regent Park, Toronto
# 2      M5B  Downtown Toronto          Ryerson          Ryerson, Toronto
# 3      M5B  Downtown Toronto  Garden District  Garden District, Toronto
# 4      M5C  Downtown Toronto   St. James Town   St. James Town, Toronto
#
#     Latitude  Longitude
# 0  43.640080 -79.380150
# 1  43.660706 -79.360457
# 2  43.658153 -79.379080
# 3  43.656502 -79.377128
# 4  43.669403 -79.372704

# %%
trtdowntown_data.drop(['Postcode', 'Neighbourhood_Toronto'], axis=1, inplace=True)

# %%
trtdowntown_data.head()
# Out:
#             Borough    Neighbourhood   Latitude  Longitude
# 0  Downtown Toronto     Harbourfront  43.640080 -79.380150
# 1  Downtown Toronto      Regent Park  43.660706 -79.360457
# 2  Downtown Toronto          Ryerson  43.658153 -79.379080
# 3  Downtown Toronto  Garden District  43.656502 -79.377128
# 4  Downtown Toronto   St. James Town  43.669403 -79.372704

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Grpahic Map of two areas

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods_ny['Latitude'],
                                           neighborhoods_ny['Longitude'],
                                           neighborhoods_ny['Borough'],
                                           neighborhoods_ny['Neighborhood']):
    label = '{}, {}'.format(neighborhoods_ny, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of Manhattan using latitude and longitude values
map_trtdowntown = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(trtdowntown_data['Latitude'],
                           trtdowntown_data['Longitude'],
                           trtdowntown_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_trtdowntown)  
    
map_trtdowntown

# %%
CLIENT_ID = '2OGJEGMXUMQB4OESKUJ22DTXAZAYAGPYT1OR310CXAULRYDE' # your Foursquare ID
CLIENT_SECRET = 'ZD3ZKJOB2P2DRCSEONN31KSMT4OBCFMTIPQNOF3T3FJIQJBA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2OGJEGMXUMQB4OESKUJ22DTXAZAYAGPYT1OR310CXAULRYDE
# CLIENT_SECRET:ZD3ZKJOB2P2DRCSEONN31KSMT4OBCFMTIPQNOF3T3FJIQJBA

# %% [markdown]
# ### Leverage Foursquare for details

# %%
def getNearbyVenuesTrt(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
def getNearbyVenuesNy(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
trt_venues = getNearbyVenuesTrt(names=trtdowntown_data['Neighbourhood'],
                            latitudes=trtdowntown_data['Latitude'],
                            longitudes=trtdowntown_data['Longitude'])
# Out:
# Harbourfront
# Regent Park
# Ryerson
# Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Harbourfront East
# Toronto Islands
# Union Station
# Design Exchange
# Toronto Dominion Centre
# Commerce Court
# Victoria Hotel
# Harbord
# University of Toronto
# Chinatown
# Grange Park
# Kensington Market
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley

# %%
# type your answer here

manhattan_venues = getNearbyVenuesNy(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
trt_venues.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Harbourfront               43.64008               -79.38015
# 1  Harbourfront               43.64008               -79.38015
# 2  Harbourfront               43.64008               -79.38015
# 3  Harbourfront               43.64008               -79.38015
# 4  Harbourfront               43.64008               -79.38015
#
#                  Venue  Venue Latitude  Venue Longitude       Venue Category
# 0  Harbour Square Park       43.639253       -79.378395                 Park
# 1         Lake Ontario       43.638945       -79.379665                 Lake
# 2         Harbourfront       43.639526       -79.380688         Neighborhood
# 3          BeaverTails       43.639899       -79.380197               Bakery
# 4                 Miku       43.641374       -79.377531  Japanese Restaurant

# %%
manhattan_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066       Arturo's
# 1  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066      Starbucks
# 4  Marble Hill              40.876551               -73.91066        Dunkin'
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       40.874412       -73.910271    Pizza Place
# 1       40.876844       -73.906204    Yoga Studio
# 2       40.880404       -73.908937          Diner
# 3       40.877531       -73.905582    Coffee Shop
# 4       40.877136       -73.906666     Donut Shop

# %%
trt_venues['Venue Category'].value_counts()
# Out:
# Coffee Shop                        235
# Café                               131
# Restaurant                          83
# Hotel                               81
# Italian Restaurant                  58
# Pizza Place                         53
# Bakery                              53
# Japanese Restaurant                 50
# Bar                                 44
# Gym                                 37
# American Restaurant                 35
# Vegetarian / Vegan Restaurant       33
# Steakhouse                          33
# Gastropub                           33
# Sandwich Place                      31
# Park                                29
# Sushi Restaurant                    28
# Deli / Bodega                       28
# Grocery Store                       28
# Seafood Restaurant                  26
# Burger Joint                        26
# Breakfast Spot                      25
# Beer Bar                            25
# Chinese Restaurant                  25
# Thai Restaurant                     24
# Fast Food Restaurant                24
# Pub                                 23
# Tea Room                            23
# Ice Cream Shop                      21
# Art Gallery                         20
# Cocktail Bar                        18
# Clothing Store                      18
# Korean Restaurant                   18
# Salad Place                         18
# Indian Restaurant                   17
# Bookstore                           16
# Mexican Restaurant                  15
# Asian Restaurant                    15
# Cosmetics Shop                      15
# Theater                             15
# Fried Chicken Joint                 14
# Ramen Restaurant                    14
# Sporting Goods Shop                 14
# Diner                               14
# New American Restaurant             13
# Bubble Tea Shop                     13
# Shopping Mall                       13
# Concert Hall                        13
# Dessert Shop                        13
# Music Venue                         12
# French Restaurant                   12
# Middle Eastern Restaurant           11
# Wine Bar                            11
# Bank                                11
# Plaza                               11
# Lounge                              11
# Food Court                          11
# Caribbean Restaurant                10
# Gym / Fitness Center                10
# Spa                                 10
# Brewery                              9
# Museum                               9
# Hotel Bar                            9
# Movie Theater                        9
# Yoga Studio                          9
# Vietnamese Restaurant                9
# Arts & Crafts Store                  9
# Farmers Market                       9
# Sports Bar                           9
# Dumpling Restaurant                  9
# Dance Studio                         8
# Salon / Barbershop                   8
# Gluten-free Restaurant               8
# Smoothie Shop                        8
# Supermarket                          8
# Greek Restaurant                     8
# Furniture / Home Store               8
# History Museum                       8
# Bistro                               8
# Tailor Shop                          7
# Record Shop                          7
# Taco Place                           7
# Convenience Store                    7
# Jazz Club                            7
# Scenic Lookout                       7
# Creperie                             7
# Hostel                               7
# Mediterranean Restaurant             7
# Beer Store                           7
# Shoe Store                           7
# Food Truck                           6
# Electronics Store                    6
# Video Game Store                     6
# Playground                           6
# Soup Place                           6
# Event Space                          6
# Office                               6
# Burrito Place                        6
# Pharmacy                             6
# Noodle House                         6
# Irish Pub                            6
# Basketball Stadium                   6
# Poke Place                           5
# Food & Drink Shop                    5
# Department Store                     5
# Performing Arts Venue                5
# Juice Bar                            5
# Latin American Restaurant            5
# Speakeasy                            5
# Gift Shop                            5
# Filipino Restaurant                  5
# Comfort Food Restaurant              5
# Smoke Shop                           4
# Discount Store                       4
# Paper / Office Supplies Store        4
# Whisky Bar                           4
# Liquor Store                         4
# Falafel Restaurant                   4
# Lake                                 4
# Neighborhood                         4
# General Travel                       4
# Monument / Landmark                  4
# Toy / Game Store                     4
# Ethiopian Restaurant                 4
# Train Station                        4
# Fountain                             4
# Church                               4
# Cheese Shop                          4
# Persian Restaurant                   3
# Boutique                             3
# Library                              3
# Snack Place                          3
# Skating Rink                         3
# Dog Run                              3
# Market                               3
# Gay Bar                              3
# Pet Store                            3
# Campground                           3
# Baseball Stadium                     3
# Women's Store                        3
# Convention Center                    3
# Modern European Restaurant           3
# Bike Rental / Bike Share             3
# Lingerie Store                       3
# Poutine Place                        3
# Gym Pool                             3
# BBQ Joint                            3
# Eastern European Restaurant          3
# Molecular Gastronomy Restaurant      3
# Bus Stop                             3
# Bagel Shop                           3
# Aquarium                             3
# Gaming Cafe                          3
# Belgian Restaurant                   3
# Hotpot Restaurant                    3
# Gourmet Shop                         3
# Video Store                          2
# Sculpture Garden                     2
# Exhibit                              2
# Comedy Club                          2
# Butcher                              2
# Fish Market                          2
# Organic Grocery                      2
# Fish & Chips Shop                    2
# Comic Shop                           2
# Miscellaneous Shop                   2
# Optical Shop                         2
# Sri Lankan Restaurant                2
# Nightclub                            2
# Martial Arts Dojo                    2
# Pie Shop                             2
# University                           2
# Men's Store                          2
# Donut Shop                           2
# College Rec Center                   2
# Thrift / Vintage Store               2
# Massage Studio                       2
# General Entertainment                2
# Souvlaki Shop                        2
# Dim Sum Restaurant                   1
# Beer Garden                          1
# Building                             1
# Hobby Shop                           1
# Health Food Store                    1
# Strip Club                           1
# Art Museum                           1
# Beach                                1
# Rock Climbing Spot                   1
# Peruvian Restaurant                  1
# Outdoor Supply Store                 1
# Castle                               1
# Adult Boutique                       1
# Tanning Salon                        1
# Bike Shop                            1
# Tapas Restaurant                     1
# School                               1
# Golf Course                          1
# Wings Joint                          1
# Bed & Breakfast                      1
# Pool                                 1
# Bus Station                          1
# Farm                                 1
# Harbor / Marina                      1
# Udon Restaurant                      1
# Costume Shop                         1
# Bowling Alley                        1
# Theme Restaurant                     1
# Historic Site                        1
# Cantonese Restaurant                 1
# Airport Service                      1
# Gas Station                          1
# Hookah Bar                           1
# Karaoke Bar                          1
# Doner Restaurant                     1
# Brazilian Restaurant                 1
# Camera Store                         1
# Hot Dog Joint                        1
# Auto Dealership                      1
# Cupcake Shop                         1
# Hospital                             1
# Mobile Phone Shop                    1
# Sake Bar                             1
# Portuguese Restaurant                1
# Hawaiian Restaurant                  1
# Opera House                          1
# Animal Shelter                       1
# Colombian Restaurant                 1
# Cycle Studio                         1
# Other Great Outdoors                 1
# Taiwanese Restaurant                 1
# Spanish Restaurant                   1
# Jewelry Store                        1
# Other Nightlife                      1
# Street Art                           1
# Kids Store                           1
# Athletics & Sports                   1
# Pool Hall                            1
# African Restaurant                   1
# Indie Movie Theater                  1
# Afghan Restaurant                    1
# College Arts Building                1
# Tunnel                               1
# Hardware Store                       1
# Garden                               1
# Health & Beauty Service              1
# College Gym                          1
# Name: Venue Category, dtype: int64

# %%
manhattan_venues['Venue Category'].value_counts()
# Out:
# Italian Restaurant                          125
# Coffee Shop                                 122
# American Restaurant                          82
# Café                                         80
# Bakery                                       72
# Pizza Place                                  70
# Hotel                                        67
# Park                                         65
# Gym                                          62
# Gym / Fitness Center                         58
# Mexican Restaurant                           56
# Cocktail Bar                                 56
# French Restaurant                            53
# Spa                                          51
# Bar                                          50
# Sushi Restaurant                             49
# Chinese Restaurant                           47
# Japanese Restaurant                          45
# Sandwich Place                               45
# Wine Shop                                    44
# Wine Bar                                     42
# Ice Cream Shop                               41
# Clothing Store                               40
# Cosmetics Shop                               39
# Deli / Bodega                                39
# Seafood Restaurant                           37
# Yoga Studio                                  36
# Indian Restaurant                            32
# Grocery Store                                32
# Art Gallery                                  30
# Burger Joint                                 30
# Mediterranean Restaurant                     30
# Theater                                      30
# Thai Restaurant                              29
# Juice Bar                                    26
# New American Restaurant                      26
# Bookstore                                    26
# Steakhouse                                   26
# Vegetarian / Vegan Restaurant                25
# Boutique                                     24
# Dessert Shop                                 23
# Salon / Barbershop                           22
# Sporting Goods Shop                          21
# Greek Restaurant                             21
# Restaurant                                   21
# Furniture / Home Store                       21
# Korean Restaurant                            20
# Bagel Shop                                   20
# Ramen Restaurant                             20
# Vietnamese Restaurant                        19
# Gift Shop                                    19
# Women's Store                                18
# Salad Place                                  18
# Cycle Studio                                 18
# Plaza                                        17
# Gourmet Shop                                 17
# Playground                                   17
# Pub                                          16
# Diner                                        16
# Latin American Restaurant                    16
# Spanish Restaurant                           15
# Dog Run                                      15
# Food Truck                                   15
# Pet Store                                    15
# Supermarket                                  14
# Pharmacy                                     14
# Taco Place                                   13
# Hotel Bar                                    13
# Cupcake Shop                                 12
# Asian Restaurant                             12
# Lounge                                       12
# Fried Chicken Joint                          11
# Liquor Store                                 11
# Men's Store                                  11
# Performing Arts Venue                        11
# Speakeasy                                    11
# Cuban Restaurant                             10
# Bubble Tea Shop                              10
# Shoe Store                                   10
# Department Store                             10
# Concert Hall                                  9
# Caribbean Restaurant                          9
# Optical Shop                                  9
# Lingerie Store                                9
# Tapas Restaurant                              9
# Gastropub                                     9
# Scenic Lookout                                9
# Health & Beauty Service                       8
# Martial Arts Dojo                             8
# Market                                        8
# Beer Bar                                      8
# Food Court                                    8
# Falafel Restaurant                            8
# Exhibit                                       8
# Jazz Club                                     8
# Pilates Studio                                8
# Tea Room                                      8
# Event Space                                   8
# Garden                                        8
# Nightclub                                     7
# Farmers Market                                7
# Tennis Court                                  7
# Roof Deck                                     7
# Dance Studio                                  7
# Historic Site                                 7
# Indie Movie Theater                           7
# Electronics Store                             7
# Breakfast Spot                                7
# Donut Shop                                    7
# Museum                                        7
# Smoke Shop                                    7
# Dumpling Restaurant                           6
# Nail Salon                                    6
# Jewelry Store                                 6
# Building                                      6
# Middle Eastern Restaurant                     6
# Bank                                          6
# History Museum                                6
# Rock Club                                     6
# Indie Theater                                 6
# Music Venue                                   6
# Cheese Shop                                   5
# Snack Place                                   5
# Massage Studio                                5
# Tailor Shop                                   5
# School                                        5
# Movie Theater                                 5
# Mobile Phone Shop                             5
# Burrito Place                                 5
# Paper / Office Supplies Store                 5
# Health Food Store                             5
# Boxing Gym                                    5
# Monument / Landmark                           5
# Comedy Club                                   5
# Accessories Store                             5
# BBQ Joint                                     5
# Turkish Restaurant                            5
# Thrift / Vintage Store                        5
# Noodle House                                  5
# Peruvian Restaurant                           5
# Poke Place                                    5
# Australian Restaurant                         5
# Toy / Game Store                              5
# Miscellaneous Shop                            4
# Design Studio                                 4
# Dim Sum Restaurant                            4
# Memorial Site                                 4
# Record Shop                                   4
# Candy Store                                   4
# Tattoo Parlor                                 4
# Beer Garden                                   4
# Residential Building (Apartment / Condo)      4
# Ethiopian Restaurant                          4
# Argentinian Restaurant                        4
# Trail                                         4
# Arts & Crafts Store                           4
# Hawaiian Restaurant                           4
# Beer Store                                    4
# Supplement Shop                               4
# Pool                                          4
# General Entertainment                         4
# Frozen Yogurt Shop                            4
# Szechuan Restaurant                           4
# Southern / Soul Food Restaurant               3
# Convenience Store                             3
# Malay Restaurant                              3
# Athletics & Sports                            3
# Karaoke Bar                                   3
# Jewish Restaurant                             3
# Shanghai Restaurant                           3
# Creperie                                      3
# Music School                                  3
# Rental Car Location                           3
# Opera House                                   3
# Arepa Restaurant                              3
# Public Art                                    3
# Hobby Shop                                    3
# Antique Shop                                  3
# Art Museum                                    3
# Fast Food Restaurant                          3
# Soup Place                                    3
# Japanese Curry Restaurant                     3
# Organic Grocery                               3
# Food & Drink Shop                             3
# Sake Bar                                      3
# Flower Shop                                   3
# African Restaurant                            3
# Hot Dog Joint                                 3
# Chocolate Shop                                3
# Bike Rental / Bike Share                      3
# Kids Store                                    3
# Sculpture Garden                              2
# Fountain                                      2
# Gay Bar                                       2
# Bistro                                        2
# Wings Joint                                   2
# Taiwanese Restaurant                          2
# Austrian Restaurant                           2
# Library                                       2
# Shopping Mall                                 2
# Bus Station                                   2
# Pet Café                                      2
# Harbor / Marina                               2
# Strip Club                                    2
# Irish Pub                                     2
# Video Game Store                              2
# Discount Store                                2
# Boat or Ferry                                 2
# Brazilian Restaurant                          2
# Bridal Shop                                   2
# Butcher                                       2
# Baseball Field                                2
# Street Art                                    2
# Israeli Restaurant                            2
# Hotpot Restaurant                             2
# Basketball Court                              2
# Caucasian Restaurant                          2
# High School                                   2
# Whisky Bar                                    2
# Paella Restaurant                             2
# Climbing Gym                                  2
# Camera Store                                  2
# Flea Market                                   2
# Udon Restaurant                               2
# Community Center                              2
# Watch Shop                                    2
# Adult Boutique                                2
# Heliport                                      2
# Gas Station                                   2
# Sports Bar                                    2
# Filipino Restaurant                           2
# German Restaurant                             2
# Eastern European Restaurant                   2
# Hardware Store                                2
# Used Bookstore                                2
# Bike Shop                                     2
# Moroccan Restaurant                           2
# Newsstand                                     2
# Dive Bar                                      1
# College Theater                               1
# Resort                                        1
# Volleyball Court                              1
# Hookah Bar                                    1
# Bus Stop                                      1
# Russian Restaurant                            1
# Cajun / Creole Restaurant                     1
# Pie Shop                                      1
# Business Service                              1
# Piano Bar                                     1
# Himalayan Restaurant                          1
# Social Club                                   1
# Venezuelan Restaurant                         1
# Medical Center                                1
# Arcade                                        1
# Theme Park Ride / Attraction                  1
# Afghan Restaurant                             1
# Board Shop                                    1
# Gymnastics Gym                                1
# Club House                                    1
# Animal Shelter                                1
# Soba Restaurant                               1
# Swiss Restaurant                              1
# English Restaurant                            1
# Rock Climbing Spot                            1
# Outdoor Sculpture                             1
# Lebanese Restaurant                           1
# North Indian Restaurant                       1
# College Academic Building                     1
# Hostel                                        1
# Pakistani Restaurant                          1
# Outdoors & Recreation                         1
# Auto Workshop                                 1
# College Gym                                   1
# Gym Pool                                      1
# Tiki Bar                                      1
# Waterfront                                    1
# Spiritual Center                              1
# Video Store                                   1
# Gaming Cafe                                   1
# Baby Store                                    1
# Shipping Store                                1
# Tennis Stadium                                1
# Kosher Restaurant                             1
# Daycare                                       1
# Fish Market                                   1
# Golf Course                                   1
# Cafeteria                                     1
# Circus                                        1
# Molecular Gastronomy Restaurant               1
# Food Stand                                    1
# Pet Service                                   1
# Coworking Space                               1
# Other Nightlife                               1
# Bridge                                        1
# Dry Cleaner                                   1
# Skate Park                                    1
# Herbs & Spices Store                          1
# Cambodian Restaurant                          1
# Ski Shop                                      1
# College Bookstore                             1
# Kebab Restaurant                              1
# Tech Startup                                  1
# Pastry Shop                                   1
# South American Restaurant                     1
# Non-Profit                                    1
# Mini Golf                                     1
# Bus Line                                      1
# Drugstore                                     1
# Photography Studio                            1
# Laundry Service                               1
# South Indian Restaurant                       1
# Veterinarian                                  1
# Empanada Restaurant                           1
# Office                                        1
# General College & University                  1
# Czech Restaurant                              1
# Duty-free Shop                                1
# Shoe Repair                                   1
# Rest Area                                     1
# Garden Center                                 1
# Persian Restaurant                            1
# Big Box Store                                 1
# Auditorium                                    1
# Recreation Center                             1
# Tree                                          1
# Tourist Information Center                    1
# Cantonese Restaurant                          1
# Scandinavian Restaurant                       1
# Modern European Restaurant                    1
# Sports Club                                   1
# Weight Loss Center                            1
# Metro Station                                 1
# Bike Trail                                    1
# College Cafeteria                             1
# Name: Venue Category, dtype: int64

# %%
ny_top = manhattan_venues['Venue Category'].value_counts()

# %%
trt_top = trt_venues['Venue Category'].value_counts()
trt_top['Coffee Shop']
# Out:
# 235

# %%
combine_list = ny_top.keys()[:10]

for item in trt_top.keys()[:10]:
    if item not in combine_list:
        combine_list = np.append(combine_list, item)
combine_list
# Out:
# array(['Italian Restaurant', 'Coffee Shop', 'American Restaurant', 'Café',
#        'Bakery', 'Pizza Place', 'Hotel', 'Park', 'Gym',
#        'Gym / Fitness Center', 'Restaurant', 'Japanese Restaurant', 'Bar'],
#       dtype=object)

# %%
venues_df = pd.DataFrame(columns=['venue_name', 'trt', 'ny'])
venues_df['venue_name'] = combine_list
trt_list = []
ny_list = []
for item in combine_list:
    if item in trt_top.keys():
        trt_list.append(trt_top[item])
    else:
        trt_list(0)
    if item in ny_top.keys():
        ny_list.append(ny_top[item])
    else:
        ny_list.append(0)
venues_df['trt'] = trt_list
venues_df['ny'] = ny_list
venues_df
# Out:
#               venue_name  trt   ny
# 0     Italian Restaurant   58  125
# 1            Coffee Shop  235  122
# 2    American Restaurant   35   82
# 3                   Café  131   80
# 4                 Bakery   53   72
# 5            Pizza Place   53   70
# 6                  Hotel   81   67
# 7                   Park   29   65
# 8                    Gym   37   62
# 9   Gym / Fitness Center   10   58
# 10            Restaurant   83   21
# 11   Japanese Restaurant   50   45
# 12                   Bar   44   50

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig, ax = plt.subplots(figsize=(8,4))
plt.setp(ax.get_xticklabels(), rotation=90)
sns.scatterplot(x="venue_name", y="trt", data=venues_df)
sns.scatterplot(x="venue_name", y="ny", data=venues_df)

# %%
from scipy.stats import f_oneway
trt_ = venues_df['trt']
ny_ = venues_df['ny']
f_oneway(trt_, ny_)
# Out:
# F_onewayResult(statistic=0.0073466389126974185, pvalue=0.9324059881993899)

# %% [markdown]
# pvalue >> 0.05 which indicates that the top 10 venues in Toronto Downtown and Manhattan have no obvious difference. The count of Coffee Shop, Hotel, Café, Restaurant, Gastropub have similarity.
